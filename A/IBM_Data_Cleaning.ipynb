# %%
# For data manipulation
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
import io
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv('/content/gdrive/MyDrive/train.csv')

# %%
df.head()
# Out:
#    Deal_title                      Lead_name               Industry  \
# 0  TitleM5DZY  Davis, Perkins and Bishop Inc            Restaurants
# 1  TitleKIW18                 Bender PLC LLC  Construction Services
# 2  TitleFXSDN          Carter-Henry and Sons      Hospitals/Clinics
# 3  TitlePSK4Y                 Garcia Ltd Ltd            Real Estate
# 4  Title904GV               Lee and Sons PLC     Financial Services
#
#   Deal_value Weighted_amount Date_of_creation      Pitch  \
# 0    320506$      2067263.7$       2020-03-29  Product_2
# 1     39488$       240876.8$       2019-07-10  Product_2
# 2    359392$      2407926.4$       2019-07-27  Product_1
# 3     76774$       468321.4$       2021-01-30  Product_2
# 4    483896$             NaN       2019-05-22  Product_2
#
#              Contact_no             Lead_revenue Fund_category  ...  \
# 0          607.447.7883         50 - 100 Million    Category 2  ...
# 1          892-938-9493  500 Million - 1 Billion    Category 4  ...
# ...

# %%
#checking dataframe columns
df.columns
# Out:
# Index(['Deal_title', 'Lead_name', 'Industry', 'Deal_value', 'Weighted_amount',
#        'Date_of_creation', 'Pitch', 'Contact_no', 'Lead_revenue',
#        'Fund_category', 'Geography', 'Location', 'POC_name', 'Designation',
#        'Lead_POC_email', 'Hiring_candidate_role', 'Lead_source',
#        'Level_of_meeting', 'Last_lead_update', 'Internal_POC', 'Resource',
#        'Internal_rating', 'Success_probability'],
#       dtype='object')

# %%
df.shape
# Out:
# (7007, 23)

# %%
#checking the unique values to decide which value is to be dropped
len(df.Lead_name.unique())
# Out:
# 7007

# %%
len(df.Date_of_creation	.unique())
# Out:
# 777

# %%
len(df.Internal_POC	.unique())
# Out:
# 60

# %%
#dropping the columns that are not required for modelling
df1= df.drop(["Lead_name","Contact_no","POC_name","Lead_POC_email"], axis=1)

# %%
df1.head()
# Out:
#    Deal_title               Industry Deal_value Weighted_amount  \
# 0  TitleM5DZY            Restaurants    320506$      2067263.7$
# 1  TitleKIW18  Construction Services     39488$       240876.8$
# 2  TitleFXSDN      Hospitals/Clinics    359392$      2407926.4$
# 3  TitlePSK4Y            Real Estate     76774$       468321.4$
# 4  Title904GV     Financial Services    483896$             NaN
#
#   Date_of_creation      Pitch             Lead_revenue Fund_category  \
# 0       2020-03-29  Product_2         50 - 100 Million    Category 2
# 1       2019-07-10  Product_2  500 Million - 1 Billion    Category 4
# 2       2019-07-27  Product_1  500 Million - 1 Billion    Category 4
# 3       2021-01-30  Product_2  500 Million - 1 Billion    Category 3
# 4       2019-05-22  Product_2         50 - 100 Million    Category 3
#
#   Geography                     Location               Designation  \
# 0       USA           Killeen-Temple, TX  Executive Vice President
# ...

# %%
#checking for missing values
df1.isnull().sum()
# Out:
# Deal_title                 0
# Industry                   1
# Deal_value                51
# Weighted_amount          525
# Date_of_creation           0
# Pitch                      0
# Lead_revenue               0
# Fund_category              0
# Geography                972
# Location                  11
# Designation                0
# Hiring_candidate_role      0
# Lead_source                0
# Level_of_meeting           0
# Last_lead_update         633
# Internal_POC               0
# Resource                 149
# Internal_rating            0
# Success_probability        0
# dtype: int64

# %%
df1[df1["Industry"].isnull()]
# Out:
#       Deal_title Industry Deal_value Weighted_amount Date_of_creation  \
# 4653  Title232C0      NaN    209418$      1266978.9$       2020-12-15
#
#           Pitch      Lead_revenue Fund_category Geography  Location  \
# 4653  Product_2  50 - 100 Million    Category 4     India  Pilibhit
#
#                Designation Hiring_candidate_role    Lead_source  \
# 4653  SVP/General Counsel    Landscape architect  Contact Email
#
#      Level_of_meeting Last_lead_update    Internal_POC Resource  \
# 4653          Level 1      2 days back  Hameier,Kurt E       No
#
#       Internal_rating  Success_probability
# 4653                3                 56.6

# %%
#replacing the missing values and replacing it with mode
df1["Industry"] = df1["Industry"].fillna((df1["Industry"].mode()[0]))

# %%
df1[df1["Deal_value"].isnull()]
# Out:
#       Deal_title                        Industry Deal_value Weighted_amount  \
# 169   TitleKXH1L                           Banks        NaN      1023175.8$
# 381   TitleBV4VN                      Iron/Steel        NaN       668538.0$
# 448   TitleMUK48                     Real Estate        NaN             NaN
# 469   TitleXSNO6                        Software        NaN     1167666.85$
# 519   TitleK69MY                           Banks        NaN      2839513.6$
# 1016  TitleXD5MP          Network Infrastructure        NaN      2929018.9$
# 1148  TitleWB44B              Furniture/Fixtures        NaN     2432947.95$
# 1246  Title6X0QM                        Staffing        NaN      1195450.0$
# 1328  TitleDUHSS                       Insurance        NaN     2607096.45$
# 1587  TitleMPX29                           Music        NaN      408901.35$
# 1599  Title27F7I              Education/Training        NaN       224107.9$
# ...

# %%
df1["Deal_value"]= df1["Deal_value"].str.replace("$","")
df1.Deal_value.head()
# Out:
# <ipython-input-628-8d0cd6edcd96>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df1["Deal_value"]= df1["Deal_value"].str.replace("$","")
# 0    320506
# 1     39488
# 2    359392
# 3     76774
# 4    483896
# Name: Deal_value, dtype: object

# %%
#converting Deal_Value to numeric
df1["Deal_value"] = pd.to_numeric(df1["Deal_value"])
#imputing missing value in Deal_value
df1["Deal_value"] = df1["Deal_value"].fillna(df1["Deal_value"].mean())

# %%
df1[df1["Weighted_amount"].isnull()]
# Out:
#       Deal_title                   Industry  Deal_value Weighted_amount  \
# 4     Title904GV         Financial Services    483896.0             NaN
# 13    TitleNQKU6                      Banks    487351.0             NaN
# 17    TitleEWIQD                   Software    140949.0             NaN
# 23    TitleO0W9A                       REIT    207335.0             NaN
# 33    TitleQ5K7M  Automotive/Transportation    335694.0             NaN
# ...          ...                        ...         ...             ...
# 6971  Title6SSU1          Hospitals/Clinics    101621.0             NaN
# 6975  Title5441H         Financial Services    456307.0             NaN
# 6983  TitleVDKHN      Professional Services     89949.0             NaN
# 6990  Title4H88W                  Insurance    240326.0             NaN
# 7004  TitleF1FWY             Semiconductors    253608.0             NaN
#
#      Date_of_creation      Pitch             Lead_revenue Fund_category  \
# ...

# %%
# removing the $ sign
df1["Weighted_amount"]= df1["Weighted_amount"].str.replace("$","")
#converting Weighted_amount to numeric
df1["Weighted_amount"] = pd.to_numeric(df1["Weighted_amount"])
df1["Weighted_amount"] = df1["Weighted_amount"].fillna(df1["Weighted_amount"].mean())
# Out:
# <ipython-input-631-456722094f97>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df1["Weighted_amount"]= df1["Weighted_amount"].str.replace("$","")

# %%
#converting the Date_of_creation to date time
df1["Date_of_creation"] = pd.to_datetime(df1["Date_of_creation"])
df1.Date_of_creation.dtype
# Out:
# dtype('<M8[ns]')

# %%
df1[df1["Geography"].isnull()].head()
# Out:
#     Deal_title                        Industry  Deal_value  Weighted_amount  \
# 6   TitleOZQRY                           Banks    384356.0     2.709710e+06
# 10  TitleP5EAQ  Healthcare Facilities/Services    311125.0     1.851194e+06
# 13  TitleNQKU6                           Banks    487351.0     1.569884e+06
# 16  TitleBZ8I3          Other Investment Firms    390309.0     2.458947e+06
# 27  TitleWKMYP                        Trucking    380817.0     2.513392e+06
#
#    Date_of_creation      Pitch             Lead_revenue Fund_category  \
# 6        2019-11-20  Product_2  500 Million - 1 Billion    Category 1
# 10       2020-01-30  Product_1  500 Million - 1 Billion    Category 2
# 13       2020-04-25  Product_1  500 Million - 1 Billion    Category 3
# 16       2019-10-13  Product_2         50 - 100 Million    Category 2
# 27       2019-05-31  Product_2         50 - 100 Million    Category 1
#
#    Geography                                   Location  \
# ...

# %%
df1.isnull().sum()
# Out:
# Deal_title                 0
# Industry                   0
# Deal_value                 0
# Weighted_amount            0
# Date_of_creation           0
# Pitch                      0
# Lead_revenue               0
# Fund_category              0
# Geography                972
# Location                  11
# Designation                0
# Hiring_candidate_role      0
# Lead_source                0
# Level_of_meeting           0
# Last_lead_update         633
# Internal_POC               0
# Resource                 149
# Internal_rating            0
# Success_probability        0
# dtype: int64

# %%
df1.Location = df1.Location.fillna('Other')

# %%
df1.isnull().sum()
# Out:
# Deal_title                 0
# Industry                   0
# Deal_value                 0
# Weighted_amount            0
# Date_of_creation           0
# Pitch                      0
# Lead_revenue               0
# Fund_category              0
# Geography                972
# Location                   0
# Designation                0
# Hiring_candidate_role      0
# Lead_source                0
# Level_of_meeting           0
# Last_lead_update         633
# Internal_POC               0
# Resource                 149
# Internal_rating            0
# Success_probability        0
# dtype: int64

# %%
# df1["Geography"] = df1["Geography"].fillna((df1["Geography"].mode()[0]))
def state_USA(s):
    return s[-2:]
def state_USA2(s):
    return s[-2:]
USA_states_taken_from_WWW = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "OR", "DE", "FL",
                             "GA", "HI" , "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME",
                             "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH",
                             "NJ", "NM", "NY", "NC", "ND", "OH", "OK", 'PA', 'RI', 'SC',
                             'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI',"WY"]
def state(state):
  if state in USA_states_taken_from_WWW:
    return "USA"
  else:
    return "India"
def state2(state):
  if state is np.nan:
    return "USA"
  else:
    return state

# %%
df1["Location"] = df1["Location"].apply(state_USA)
df1.isnull().sum()
# df1.head()
df1["Geography"] = df1["Location"].apply(state)
# if df1['Location'] in USA_states_taken_from_WWW:
#   df1.Geography = df1.Geography.fillna('USA')
# else:
#   df1.Geography = df1.Geography.fillna('India')

# %%
df[df["Geography"] == "USA"].shape[0]
# Out:
# 3061

# %%
df1.isnull().sum()
# Out:
# Deal_title                 0
# Industry                   0
# Deal_value                 0
# Weighted_amount            0
# Date_of_creation           0
# Pitch                      0
# Lead_revenue               0
# Fund_category              0
# Geography                  0
# Location                   0
# Designation                0
# Hiring_candidate_role      0
# Lead_source                0
# Level_of_meeting           0
# Last_lead_update         633
# Internal_POC               0
# Resource                 149
# Internal_rating            0
# Success_probability        0
# dtype: int64

# %%
#we see all missing region in usa area,so replacing it with mode of usa area
df2=df1[df1["Geography"]=="USA"]
df2.head()
# Out:
#    Deal_title                  Industry  Deal_value  Weighted_amount  \
# 0  TitleM5DZY               Restaurants    320506.0        2067263.7
# 2  TitleFXSDN         Hospitals/Clinics    359392.0        2407926.4
# 3  TitlePSK4Y               Real Estate     76774.0         468321.4
# 6  TitleOZQRY                     Banks    384356.0        2709709.8
# 7  TitleV05WV  Architecture/Engineering    245205.0        1642873.5
#
#   Date_of_creation      Pitch             Lead_revenue Fund_category  \
# 0       2020-03-29  Product_2         50 - 100 Million    Category 2
# 2       2019-07-27  Product_1  500 Million - 1 Billion    Category 4
# 3       2021-01-30  Product_2  500 Million - 1 Billion    Category 3
# 6       2019-11-20  Product_2  500 Million - 1 Billion    Category 1
# 7       2020-12-22  Product_2  500 Million - 1 Billion    Category 1
#
#   Geography Location                                        Designation  \
# ...

# %%
df1["Last_lead_update"] = df1["Last_lead_update"].fillna((df1.Last_lead_update.mode()[0]))

# %%
df1["Resource"] = df1["Resource"].fillna((df1["Resource"].mode()[0]))

# %%
df1.head()
# Out:
#    Deal_title               Industry  Deal_value  Weighted_amount  \
# 0  TitleM5DZY            Restaurants    320506.0     2.067264e+06
# 1  TitleKIW18  Construction Services     39488.0     2.408768e+05
# 2  TitleFXSDN      Hospitals/Clinics    359392.0     2.407926e+06
# 3  TitlePSK4Y            Real Estate     76774.0     4.683214e+05
# 4  Title904GV     Financial Services    483896.0     1.569884e+06
#
#   Date_of_creation      Pitch             Lead_revenue Fund_category  \
# 0       2020-03-29  Product_2         50 - 100 Million    Category 2
# 1       2019-07-10  Product_2  500 Million - 1 Billion    Category 4
# 2       2019-07-27  Product_1  500 Million - 1 Billion    Category 4
# 3       2021-01-30  Product_2  500 Million - 1 Billion    Category 3
# 4       2019-05-22  Product_2         50 - 100 Million    Category 3
#
#   Geography Location               Designation  \
# 0       USA       TX  Executive Vice President
# 1     India       am    Chairman/CEO/President
# ...

# %%
df1.isna().sum()
# Out:
# Deal_title               0
# Industry                 0
# Deal_value               0
# Weighted_amount          0
# Date_of_creation         0
# Pitch                    0
# Lead_revenue             0
# Fund_category            0
# Geography                0
# Location                 0
# Designation              0
# Hiring_candidate_role    0
# Lead_source              0
# Level_of_meeting         0
# Last_lead_update         0
# Internal_POC             0
# Resource                 0
# Internal_rating          0
# Success_probability      0
# dtype: int64

# %%
df1.replace('?',np.nan,inplace=True)
df1.head()
# Out:
#    Deal_title               Industry  Deal_value  Weighted_amount  \
# 0  TitleM5DZY            Restaurants    320506.0     2.067264e+06
# 1  TitleKIW18  Construction Services     39488.0     2.408768e+05
# 2  TitleFXSDN      Hospitals/Clinics    359392.0     2.407926e+06
# 3  TitlePSK4Y            Real Estate     76774.0     4.683214e+05
# 4  Title904GV     Financial Services    483896.0     1.569884e+06
#
#   Date_of_creation      Pitch             Lead_revenue Fund_category  \
# 0       2020-03-29  Product_2         50 - 100 Million    Category 2
# 1       2019-07-10  Product_2  500 Million - 1 Billion    Category 4
# 2       2019-07-27  Product_1  500 Million - 1 Billion    Category 4
# 3       2021-01-30  Product_2  500 Million - 1 Billion    Category 3
# 4       2019-05-22  Product_2         50 - 100 Million    Category 3
#
#   Geography Location               Designation  \
# 0       USA       TX  Executive Vice President
# 1     India       am    Chairman/CEO/President
# ...

# %%
df1.to_csv('/content/gdrive/MyDrive/train_new.csv', index=False)
